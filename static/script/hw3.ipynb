# %%
import pandas as pd
file_path = '/Users/xiaoyufan/Desktop/5311/hw3/yelp_boston.csv'
df = pd.read_csv(file_path)
df
# Out:
#                              name  \
# 0                      Wheelhouse
# 1                  Tenoch Mexican
# 2                            O Ya
# 3                          Locale
# 4                  Neptune Oyster
# ..                            ...
# 338                     El Madina
# 339           The Shops at Porter
# 340  Bazaar International Gourmet
# 341          G Mart 2 Supermarket
# 342    Bonne Chance Cafe & Bakery
#
#                                                    url  review_count  \
# 0          http://www.yelp.com/biz/wheelhouse-boston-3           101
# 1        http://www.yelp.com/biz/tenoch-mexican-boston           121
# 2                  http://www.yelp.com/biz/o-ya-boston           450
# 3                http://www.yelp.com/biz/locale-boston           121
# 4        http://www.yelp.com/biz/neptune-oyster-boston          2487
# ..                                                 ...           ...
# ...

# %%
search_category = df['search category'].value_counts()
print(search_category)
# Out:
# search category
# restaurants      20
# vietnamese       20
# donuts           20
# sandwiches       20
# pizza            20
# indpak           20
# sushi            20
# japanese         20
# thai             20
# mexican          19
# ethnicmarkets    19
# newamerican      19
# coffee           18
# cafes            18
# french           18
# italian          18
# bakeries         17
# chinese          17
# Name: count, dtype: int64

# %%
categories_json = df['categories_json'].value_counts()
print(categories_json)
# Out:
# categories_json
# [["Thai", "thai"]]                                                                          14
# [["Mexican", "mexican"]]                                                                    13
# [["Sushi Bars", "sushi"], ["Japanese", "japanese"]]                                         10
# [["Coffee & Tea", "coffee"]]                                                                10
# [["Indian", "indpak"]]                                                                      10
#                                                                                             ..
# [["Cafes", "cafes"], ["Turkish", "turkish"], ["Falafel", "falafel"]]                         1
# [["Coffee & Tea", "coffee"], ["Sandwiches", "sandwiches"], ["Cafes", "cafes"]]               1
# [["Sandwiches", "sandwiches"], ["Burgers", "burgers"]]                                       1
# [["Diners", "diners"], ["Sandwiches", "sandwiches"], ["Salad", "salad"]]                     1
# ...

# %%
neighborhood = df['neighborhood'].value_counts()
print(neighborhood)
# Out:
# neighborhood
# North End             31
# South End             29
# Back Bay              29
# Chinatown             27
# Downtown              22
# Waterfront            20
# East Boston           20
# Allston/Brighton      20
# Financial District    13
# South Boston          11
# Dorchester             9
# Beacon Hill            8
# Fenway                 5
# Mission Hill           3
# Kendall Square/MIT     3
# Charlestown            3
# Jamaica Plain          2
# Harvard Square         2
# Teele Square           2
# Porter Square          2
# West Roxbury           2
# Inman Square           1
# North Cambridge        1
# Coolidge Corner        1
# Name: count, dtype: int64

# %%
rating = df['rating'].value_counts()
print(rating)
# Out:
# rating
# 4.0    199
# 4.5    115
# 3.5     22
# 5.0      7
# Name: count, dtype: int64

# %%
review_count = df['review_count'].value_counts()
review_count1 = review_count[review_count > 50000 ]
print(review_count)
# Out:
# review_count
# 89      6
# 121     6
# 17      5
# 40      5
# 16      4
#        ..
# 1290    1
# 1115    1
# 273     1
# 151     1
# 48      1
# Name: count, Length: 211, dtype: int64

# %%
columns_to_drop = ['latitude', 'longitude']
df = df.drop(columns=columns_to_drop, errors='ignore')
df
df.to_csv('/Users/xiaoyufan/Desktop/yelp_boston_new.csv', index=False)
